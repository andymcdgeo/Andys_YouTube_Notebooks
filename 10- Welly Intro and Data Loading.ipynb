# %%
#!pip install wellpathpy
#!pip install welly

# %% [markdown]
# ## Import the Required Libraries

# %%
from welly import Well
from welly import Curve

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and Explore Data from LAS File

# %%
well = Well.from_las('welly_data/L0509_comp.las')
# Out:
# /Users/andy/opt/anaconda3/lib/python3.8/site-packages/welly/curve.py:216: UserWarning: Irregular sampling in depth is not supported. Interpolating to regular basis.
#   warnings.warn(m)

# %%
well
# Out:
# Well(uwi: '', 5 curves: ['GR', 'DT', 'RHOB', 'DRHO', 'NPHI'])

# %%
well.header
# Out:
# {'name': 'L05-B-01', 'uwi': '', 'field': 'L5', 'company': 'WIN'}

# %%
well.header.name
# Out:
# 'L05-B-01'

# %%
well.header.field
# Out:
# 'L5'

# %%
well.uwi
# Out:
# ''

# %%
well.count_curves()
# Out:
# 5

# %%
well._get_curve_mnemonics()
# Out:
# ['GR', 'DT', 'RHOB', 'DRHO', 'NPHI']

# %%
well.data
# Out:
# {'GR': Curve([         nan,          nan,          nan, ..., 104.08917258,
#         103.37958247, 102.78443564]),
#  'DT': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'RHOB': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'DRHO': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'NPHI': Curve([nan, nan, nan, ..., nan, nan, nan])}

# %%
well.data['GR']
# Out:
# Curve([         nan,          nan,          nan, ..., 104.08917258,
#        103.37958247, 102.78443564])

# %%
well.data['RHOB']
# Out:
# Curve([nan, nan, nan, ..., nan, nan, nan])

# %%
well.data['GR'].read_at(3000)
# Out:
# 45.42338981346771

# %% [markdown]
# ## Welly Plotting

# %%
well.plot(extents='curve')

# %%
well.plot(tracks=['MD', 'GR'])
# Out:
# /Users/andy/opt/anaconda3/lib/python3.8/site-packages/welly/well.py:592: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
well.plot(tracks=['MD', 'GR', 'RHOB', 'NPHI'])
# Out:
# /Users/andy/opt/anaconda3/lib/python3.8/site-packages/welly/well.py:592: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
